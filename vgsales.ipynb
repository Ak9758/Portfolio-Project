# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
df = pd.read_csv(r'C:\Users\Admin\Desktop\DA Projects\vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Looking out for nulls
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
#Dropping the null values from the dataset
df=df.dropna(how='all')
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df=df.sort_values(by=['Global_Sales'],inplace=False, ascending=False)
df
# Out:
#         Rank                                             Name Platform  \
# 0          1                                       Wii Sports      Wii
# 1          2                                Super Mario Bros.      NES
# 2          3                                   Mario Kart Wii      Wii
# 3          4                                Wii Sports Resort      Wii
# 4          5                         Pokemon Red/Pokemon Blue       GB
# ...      ...                                              ...      ...
# 16181  16184                             Resistance Dual Pack      PS3
# 16182  16185                                  Princess Arthur      PSP
# 16183  16186                      Sakura-Sou no Pet na Kanojo      PSP
# 16184  16187  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2
# 16597  16600                                 Spirits & Spells      GBA
#
#          Year         Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
sns.catplot(x='Platform', y='Global_Sales', data=df, ci=None )
plt.xticks(rotation=90)
print()

# %%
sns.lineplot(data = df, x="Genre", y="Global_Sales")
plt.xticks(rotation=90)

print()
